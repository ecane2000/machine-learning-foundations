# %%
print("The machine-learning environment is ready.")
# Out:
# The machine-learning environment is ready.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# pandas: 2.3.3
# numpy: 2.0.2
# scikit-learn: 1.6.1
